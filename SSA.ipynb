# %%
import pandas as pd
import nltk

df=pd.read_csv('Data.csv', encoding = "ISO-8859-1")


#the above dataframe has 25 column of top news for everyday in a specific time period 2000-2016
df.head()
# Out:
#          Date  Label                                               Top1  \
# 0  2000-01-03      0  A 'hindrance to operations': extracts from the...
# 1  2000-01-04      0                                          Scorecard
# 2  2000-01-05      0                  Coventry caught on counter by Flo
# 3  2000-01-06      1                      Pilgrim knows how to progress
# 4  2000-01-07      1                               Hitches and Horlocks
#
#                                  Top2  \
# 0                           Scorecard
# 1                 The best lake scene
# 2  United's rivals on the road to Rio
# 3                 Thatcher facing ban
# 4      Beckham off but United survive
#
#                                             Top3  \
# 0                Hughes' instant hit buoys Blues
# 1                  Leader: German sleaze inquiry
# 2  Thatcher issues defence before trial by video
# 3        McIlroy calls for Irish fighting spirit
# 4                        Breast cancer screening
#
#                                             Top4  \
# 0       Jack gets his skates on at ice-cold Alex
# 1                                  Cheerio, boyo
# 2  Police help Smith lay down the law at Everton
# 3                Leicester bin stadium blueprint
# 4                                    Alan Parker
#
#                                           Top5  \
# 0       Chaos as Maracana builds up for United
# 1                     The main recommendations
# 2  Tale of Trautmann bears two more retellings
# 3               United braced for Mexican wave
# 4      Guardian readers: are you all whingers?
#
#                                                 Top6  \
# 0  Depleted Leicester prevail as Elliott spoils E...
# 1                             Has Cubie killed fees?
# 2                                England on the rack
# 3  Auntie back in fashion, even if the dress look...
# 4                                   Hollywood Beyond
#
#                                               Top7  \
# 0                 Hungry Spurs sense rich pickings
# 1                           Has Cubie killed fees?
# 2  Pakistan retaliate with call for video of Walsh
# 3                    Shoaib appeal goes to the top
# 4                               Ashes and diamonds
#
#                                                 Top8  ...  \
# 0                  Gunners so wide of an easy target  ...
# 1                             Has Cubie killed fees?  ...
# 2               Cullinan continues his Cape monopoly  ...
# 3  Hussain hurt by 'shambles' but lays blame on e...  ...
# 4                   Whingers - a formidable minority  ...
#
#                                                Top16  \
# 0           Flintoff injury piles on woe for England
# 1                               On the critical list
# 2                        South Melbourne (Australia)
# 3  Putin admits Yeltsin quit to give him a head s...
# 4                             Most everywhere:  UDIs
#
#                                                Top17  \
# 0  Hunters threaten Jospin with new battle of the...
# 1                          The timing of their lives
# 2                                    Necaxa (Mexico)
# 3         BBC worst hit as digital TV begins to bite
# 4                       Most wanted:  Chloe lunettes
#
#                                             Top18  \
# 0             Kohl's successor drawn into scandal
# 1                                     Dear doctor
# 2                             Real Madrid (Spain)
# 3                     How much can you pay for...
# 4  Return of the cane 'completely off the agenda'
#
#                                                Top19  \
# 0               The difference between men and women
# 1  Irish court halts IRA man's extradition to Nor...
# 2                          Raja Casablanca (Morocco)
# 3                                 Christmas glitches
# 4                   From Sleepy Hollow to Greeneland
#
#                                                Top20  \
# 0                Sara Denver, nurse turned solicitor
# 1  Burundi peace initiative fades after rebels re...
# 2                               Corinthians (Brazil)
# 3  Upending a table, Chopping a line and Scoring ...
# 4              Blunkett outlines vision for over 11s
#
#                                                Top21  \
# 0     Diana's landmine crusade put Tories in a panic
# 1               PE points the way forward to the ECB
# 2                                 Tony's pet project
# 3   Scientific evidence 'unreliable', defence claims
# 4  Embattled Dobson attacks 'play now, pay later'...
#
#                                                Top22  \
# 0  Yeltsin's resignation caught opposition flat-f...
# 1  Campaigners keep up pressure on Nazi war crime...
# 2                            Al Nassr (Saudi Arabia)
# 3     Fusco wins judicial review in extradition case
# 4                                  Doom and the Dome
#
#                              Top23  \
# 0                 Russian roulette
# 1                   Jane Ratcliffe
# 2                Ideal Holmes show
# 3    Rebels thwart Russian advance
# 4  What is the north-south divide?
#
#                                                Top24  \
# 0                                           Sold out
# 1  Yet more things you wouldn't know without the ...
# 2               Pinochet leaves hospital after tests
# 3               Blair orders shake-up of failing NHS
# 4                          Aitken released from jail
#
#                           Top25
# 0            Recovering a title
# 1  Millennium bug fails to bite
# 2                  Useful links
# 3   Lessons of law's hard heart
# 4                    Gone aloft
#
# [5 rows x 27 columns]

# %%
df.tail()
# Out:
#             Date  Label                                               Top1  \
# 4096  2016-06-27      0  Barclays and RBS shares suspended from trading...
# 4097  2016-06-28      1  2,500 Scientists To Australia: If You Want To ...
# 4098  2016-06-29      1                   Explosion At Airport In Istanbul
# 4099  2016-06-30      1  Jamaica proposes marijuana dispensers for tour...
# 4100  2016-07-01      1  A 117-year-old woman in Mexico City finally re...
#
#                                                    Top2  \
# 4096  Pope says Church should ask forgiveness from g...
# 4097  The personal details of 112,000 French police ...
# 4098  Yemeni former president: Terrorism is the offs...
# 4099  Stephen Hawking says pollution and 'stupidity'...
# 4100   IMF chief backs Athens as permanent Olympic host
#
#                                                    Top3  \
# 4096  Poland 'shocked' by xenophobic abuse of Poles ...
# 4097  S&amp;P cuts United Kingdom sovereign credit r...
# 4098  UK must accept freedom of movement to access E...
# 4099  Boris Johnson says he will not run for Tory pa...
# 4100  The president of France says if Brexit won, so...
#
#                                                    Top4  \
# 4096  There will be no second referendum, cabinet ag...
# 4097                Huge helium deposit found in Africa
# 4098  Devastated: scientists too late to captive bre...
# 4099  Six gay men in Ivory Coast were abused and for...
# 4100  British Man Who Must Give Police 24 Hours' Not...
#
#                                                    Top5  \
# 4096      Scotland welcome to join EU, Merkel ally says
# 4097  CEO of the South African state broadcaster qui...
# 4098  British Labor Party leader Jeremy Corbyn loses...
# 4099  Switzerland denies citizenship to Muslim immig...
# 4100  100+ Nobel laureates urge Greenpeace to stop o...
#
#                                                    Top6  \
# 4096  Sterling dips below Friday's 31-year low amid ...
# 4097  Brexit cost investors $2 trillion, the worst o...
# 4098  A Muslim Shop in the UK Was Just Firebombed Wh...
# 4099  Palestinian terrorist stabs israeli teen girl ...
# 4100  Brazil: Huge spike in number of police killing...
#
#                                                    Top7  \
# 4096  No negative news about South African President...
# 4097  Hong Kong democracy activists call for return ...
# 4098  Mexican Authorities Sexually Torture Women in ...
# 4099  Puerto Rico will default on $1 billion of debt...
# 4100  Austria's highest court annuls presidential el...
#
#                                                    Top8  ...  \
# 4096  Surge in Hate Crimes in the U.K. Following U.K...  ...
# 4097  Brexit: Iceland president says UK can join 'tr...  ...
# 4098            UK shares and pound continue to recover  ...
# 4099  Republic of Ireland fans to be awarded medal f...  ...
# 4100  Facebook wins privacy case, can track any Belg...  ...
#
#                                                   Top16  \
# 4096  German lawyers to probe Erdogan over alleged w...
# 4097  US, Canada and Mexico pledge 50% of power from...
# 4098  Escape Tunnel, Dug by Hand, Is Found at Holoca...
# 4099  Googles free wifi at Indian railway stations i...
# 4100  The United States has placed Myanmar, Uzbekist...
#
#                                                   Top17  \
# 4096  Boris Johnson says the UK will continue to "in...
# 4097  There is increasing evidence that Australia is...
# 4098  The land under Beijing is sinking by as much a...
# 4099  Mounting evidence suggests 'hobbits' were wipe...
# 4100  S&amp;P revises European Union credit rating t...
#
#                                                   Top18  \
# 4096  Richard Branson is calling on the UK governmen...
# 4097  Richard Branson, the founder of Virgin Group, ...
# 4098  Car bomb and Anti-Islamic attack on Mosque in ...
# 4099  The men who carried out Tuesday's terror attac...
# 4100  India gets $1 billion loan from World Bank for...
#
#                                                   Top19  \
# 4096             Turkey 'sorry for downing Russian jet'
# 4097  37,000-yr-old skull from Borneo reveals surpri...
# 4098  Emaciated lions in Taiz Zoo are trapped in blo...
# 4099  Calls to suspend Saudi Arabia from UN Human Ri...
# 4100  U.S. sailors detained by Iran spoke too much u...
#
#                                                   Top20  \
# 4096  Edward Snowden lawyer vows new push for pardon...
# 4097  Palestinians stone Western Wall worshipers; po...
# 4098  Rupert Murdoch describes Brexit as 'wonderful'...
# 4099  More Than 100 Nobel Laureates Call Out Greenpe...
# 4100  Mass fish kill in Vietnam solved as Taiwan ste...
#
#                                                   Top21  \
# 4096  Brexit opinion poll reveals majority don't wan...
# 4097  Jean-Claude Juncker asks Farage: Why are you h...
# 4098       More than 40 killed in Yemen suicide attacks
# 4099  British pedophile sentenced to 85 years in US ...
# 4100  Philippines president Rodrigo Duterte urges pe...
#
#                                                   Top22  \
# 4096  Conservative MP Leave Campaigner: "The leave c...
# 4097  "Romanians for Remainians" offering a new home...
# 4098  Google Found Disastrous Symantec and Norton Vu...
# 4099  US permitted 1,200 offshore fracks in Gulf of ...
# 4100  Spain arrests three Pakistanis accused of prom...
#
#                                                   Top23  \
# 4096  Economists predict UK recession, further weake...
# 4097  Brexit: Gibraltar in talks with Scotland to st...
# 4098  Extremist violence on the rise in Germany: Dom...
# 4099  We will be swimming in ridicule - French beach...
# 4100  Venezuela, where anger over food shortages is ...
#
#                                                   Top24  \
# 4096  New EU 'superstate plan by France, Germany: Cr...
# 4097                   8 Suicide Bombers Strike Lebanon
# 4098  BBC News: Labour MPs pass Corbyn no-confidence...
# 4099  UEFA says no minutes of silence for Istanbul v...
# 4100  A Hindu temple worker has been killed by three...
#
#                                                   Top25
# 4096  Pakistani clerics declare transgender marriage...
# 4097  Mexico's security forces routinely use 'sexual...
# 4098  Tiny New Zealand town with 'too many jobs' lau...
# 4099  Law Enforcement Sources: Gun Used in Paris Ter...
# 4100  Ozone layer hole seems to be healing - US &amp...
#
# [5 rows x 27 columns]

# %%
#cleaning and preparing the data
#the first column is date , the second is label if the stock price increase or the opposite
#so we can remove the date column as we dont need it for our model, but befor that we can use it to split our data frame for test and train.

df['Date'] = pd.to_datetime(df['Date'])
split_date = '20130101'
train_df = df[df['Date'] < split_date]
test_df = df[df['Date'] >= split_date]
#print(df['Date'])

train_df.tail()
# Out:
#            Date  Label                                               Top1  \
# 3214 2012-12-24      0  Swaziland Bans Women From Wearing "Rape-Provok...
# 3215 2012-12-26      0  Mexico Bishop Inspires, Infuriates by Telling ...
# 3216 2012-12-27      0  Putin Says He Will Sign Bill Banning Americans...
# 3217 2012-12-28      0  A 17-year-old Indian girl who was gang-raped k...
# 3218 2012-12-31      1  A young Nepali woman returning from Saudi Arab...
#
#                                                    Top2  \
# 3214  Air strike kills dozens of Syrians trying to b...
# 3215  British Create Petition to Keep Piers Morgan i...
# 3216  PricewaterhouseCoopers sued for $900 million i...
# 3217  Belgium prosecutes Scientology as a criminal o...
# 3218  Victim's brother wants Indian gang rapists hanged
#
#                                                    Top3  \
# 3214  Mayan temple damaged in tourist 'apocalypse' f...
# 3215  Defense Department of Canada removes report on...
# 3216  India to Name &amp; Shame Rapists - Govt to po...
# 3217  China has passed a law requiring adult childre...
# 3218  Scientists fear Canada will fish bluefin tuna ...
#
#                                                    Top4  \
# 3214  Human Rights Watch: Palestinian armed groups i...
# 3215  When U.S. drones kill civilians, Yemens govern...
# 3216     Villagers join al-Qaeda after deadly US strike
# 3217  Chinese labor camp worker hides note inside Ha...
# 3218  New rights will 'effectively end homelessness'...
#
#                                                    Top5  \
# 3214               Red alert issued for Chilean volcano
# 3215  Dig Finds Evidence of Real Bethlehem - There's...
# 3216  Chemical Weapons use in Syria confirmed by def...
# 3217  Saudi detains dozens for "plotting to celebrat...
# 3218  Controversial surgery in China for addiction b...
#
#                                                    Top6  \
# 3214  From the Delhi police -- why women DESERVE to ...
# 3215  Majority of Britons support fox hunting ban le...
# 3216   Flurry of corruption revelations suggests Chi...
# 3217  First wolf sighting in the Netherlands since 1897
# 3218  A French weekly known for publishing cartoons ...
#
#                                                    Top7  \
# 3214  Canadian backlash as cannibal killer named 'ne...
# 3215  Facebook Funneled Nearly Half A Billion Pounds...
# 3216  BBC News - 33 ton aquarium bursts in shopping ...
# 3217  Catholic Priest Sparks Outrage in Italy by Cla...
# 3218  "The Opec oil cartel, led by Saudi Arabia, wil...
#
#                                                    Top8  ...  \
# 3214  Syrian Troops 'Using Killer Gas Bombs' While F...  ...
# 3215  "Faced with the threat of horse-mounted Sudane...  ...
# 3216  Brazilian cities hit by crack epidemic. 'Altho...  ...
# 3217  \nSurge in 'Honor killings' Bring Dishonor to ...  ...
# 3218  Police Trap Reveals How Afghan Insider Attacks...  ...
#
#                                                   Top16  \
# 3214  Muslim Brotherhood: Egyptians pass new constit...
# 3215  Group of Indian Jews said to be from Lost Trib...
# 3216  New Zealand's largest paper calls Kim Dotcom g...
# 3217  China has tightened its rules on internet usag...
# 3218  Afghans angry at US soldiers who drove away in...
#
#                                                   Top17  \
# 3214         Chinese school bus crash kills 11 children
# 3215  In majority-Muslim Senegal, Christmas is flour...
# 3216  China may require real name registration for i...
# 3217  US evacuates Central African Republic embassy ...
# 3218  Syrian rebels 'beheaded Christian and fed him ...
#
#                                                   Top18  \
# 3214  North Korea warns South over giant Christmas t...
# 3215  President Vladimir Putin is facing growing opp...
# 3216  Would you eat less meat to help save the plane...
# 3217    U.S. official: North Korea likely deceived U.S.
# 3218   Russia Sends Another Naval Ship to Syria - No...
#
#                                                   Top19  \
# 3214  Russian military presence in Syria poses chall...
# 3215  Policewoman who killed US aide in Kabul 'is Ir...
# 3216  World's Longest High-Speed Rail Line Opens in ...
# 3217  Iran's only female cabinet minister sacked: Pr...
# 3218  Indian rape victim was 'planning to marry man ...
#
#                                                   Top20  \
# 3214  India PM appeals for Delhi calm after rape pro...
# 3215  China cracks down on child-trafficking gangs. ...
# 3216  Ancient Conehead-Like Alien Skulls Unearthed I...
# 3217  Egypts top prosecutor orders probe against Egy...
# 3218  Pregnant US woman Caitlan Coleman missing in A...
#
#                                                   Top21  \
# 3214  Minor girl in India raped, recorded and clip u...
# 3215  An Iranian lawmaker has complained that female...
# 3216  Nine men in a small Mexican town were gunned d...
# 3217  Swedish Mother Used Christmas Gift to Murder P...
# 3218     Will Egypt's Jon Stewart be stifled? - CNN.com
#
#                                                   Top22  \
# 3214  Syrian Christians flee civil war, say they fac...
# 3215  Canada's Food Safety Rules Not Much Good if No...
# 3216  Japanese man Jiroemon Kimura to become oldest ...
# 3217  Uttar Pradesh Gang-Rape Victim Raped, Threaten...
# 3218  National Trust triess to block 100m Giant's Ca...
#
#                                                   Top23  \
# 3214  Nigeria: Islamists kidnapp French engineer bec...
# 3215  China opens world's longest high-speed rail route
# 3216  Germany: Suspected Islamists attack Indian stu...
# 3217  Official in Japan's new government hints at re...
# 3218  Pakistani Taliban execute captured policemen: ...
#
#                                                   Top24  \
# 3214  China Holds Test Run on Worlds Longest High-Sp...
# 3215              Egyptian voters back new constitution
# 3216  Russia has sent 1200+ marines to Syria - devel...
# 3217  Germany Now a Shopping Destination for Wealthy...
# 3218  German magazine mistakenly publishes obituary ...
#
#                                                   Top25
# 3214  Russias only Hindu temple faces threat of demo...
# 3215  Facebook paid 2.9m tax on 840m profits made ou...
# 3216  BBC News - India tea workers burn boss to deat...
# 3217             The police slap heard all over Bahrain
# 3218  Sex, drugs and rock and roll: Australia's othe...
#
# [5 rows x 27 columns]

# %%
test_df.head()
# Out:
#            Date  Label                                               Top1  \
# 3219 2013-01-02      1  In Pakistan: Gunmen stop a van containing teac...
# 3220 2013-01-03      0  Australian PM says abolishing compulsory votin...
# 3221 2013-01-04      1  Soccer team walks out on game in Italy after A...
# 3222 2013-01-07      0  Mother Jailed For Murdering Seven-Year-Old Son...
# 3223 2013-01-08      0  Poachers killed a family of 11 elephants in th...
#
#                                                    Top2  \
# 3219  Russia boosts space spending: Prime Minister D...
# 3220  Spanish city's locksmiths say they'll no longe...
# 3221  Obese who refuse to exercise 'could face benef...
# 3222   The IMF Has Admitted Their Economists Were Wrong
# 3223  Australia's heatwave off the scale, the Bureau...
#
#                                                    Top3  \
# 3219  Japan's Population Falls by 212,000 in 2012 (r...
# 3220  Nicolas Sarkozy DID take $50 million of Muamma...
# 3221  How to Halt the Terrorist Money Train? Step 1:...
# 3222               US drone strike kills 17 in Pakistan
# 3223  Poachers are not only killing elephants, but a...
#
#                                                    Top4  \
# 3219  Solar energy on the rise in Germany - the rece...
# 3220                     Al Jazeera Acquires Current TV
# 3221  Japanese man vacations on Syrian front lines. ...
# 3222        South Africa: Women Drinking To Harm Babies
# 3223  In a world first, McDonald's in Australia will...
#
#                                                    Top5  \
# 3219  Pakistan is developing a new generation of sma...
# 3220   Icelandic Girl Fights For Right To Her Own Name.
# 3221  Switzerland's oldest bank became the first for...
# 3222  Tweeter gets 2-year jail term for criticizing ...
# 3223  Gamers hired by father to 'kill' son in online...
#
#                                                    Top6  \
# 3219  Six women and a man, working for a health and ...
# 3220  Kim Jong-un's wife 'has given birth' in North ...
# 3221  Woman jumps from speeding train in India to av...
# 3222  China blazes trail for 'clean' nuclear power f...
# 3223  Anger online as Saudi in his 90s marries 15-ye...
#
#                                                    Top7  \
# 3219  52,000 Amerasians, the illegitimate children o...
# 3220  Indian politician attacked for alleged involve...
# 3221  Journalists at a leading Chinese newspaper hav...
# 3222  Indian Politician: "Women should be just house...
# 3223  In Bollywood films, men routinely chase and ha...
#
#                                                    Top8  ...  \
# 3219  Insight: How Colombian drug traffickers used H...  ...
# 3220  Controversial Israeli law banning too-skinny m...  ...
# 3221  Disastrous relief for Haiti: Three years on fr...  ...
# 3222        Protesters in China call for press freedoms  ...
# 3223    Outrage as Indian guru blames Delhi rape victim  ...
#
#                                                   Top16  \
# 3219  Egypt satirist faces probe for insulting presi...
# 3220                  Argentina reignites Falklands row
# 3221  Narwhal Tusk Smuggling Ring Busted - Does your...
# 3222  Australia's Mining Boom Creates Demand For Sex...
# 3223  Iran admits oil exports fall by 40 percent ami...
#
#                                                   Top17  \
# 3219  Israel will cease to exist within a decade, sa...
# 3220        Canada's Indigenous movement gains momentum
# 3221  Magazine firebombed for printing satirical 'Sh...
# 3222  Israeli firm to design San Diego desalination ...
# 3223  Environmental activist creates a fake media re...
#
#                                                   Top18  \
# 3219      Over 60,000 dead in Syria conflict, U.N. says
# 3220  Murder Charges Are Expected Against 5 Men in N...
# 3221      Bored truck driver plays war tourist in Syria
# 3222  Thousands Stranded as Crews Battle Bushfires T...
# 3223  Syria crisis: Food aid 'cannot reach a million...
#
#                                                   Top19  \
# 3219  Qatari poet jailed for insulting the state's r...
# 3220    Al Jazeera to start new U.S.-based News Channel
# 3221  BBC News - Church of England drops gay bishop ...
# 3222  Syria President Bashar Assad makes clear he wo...
# 3223  Kim Jong-Un sends 2.2 pounds of sweets to ever...
#
#                                                   Top20  \
# 3219   Egypt satirist faces probe for 'undermining' ...
# 3220  Russia restricts sale of beer to reduce proble...
# 3221  Argentina's understanding of history is laugha...
# 3222  In Asia, Ill Will Runs Deep: The resentments b...
# 3223  Fifteen year old girl repeatedly raped by her ...
#
#                                                   Top21  \
# 3219  Armed robbers hit Apple store in Paris, report...
# 3220    Icelandic girl fights for right to her own name
# 3221  Drone attacks unacceptable: Pakistan Foreign O...
# 3222  Chinese mayor apologizes for taking 5 days to ...
# 3223  New Record for German Exports Expected for 201...
#
#                                                   Top22  \
# 3219  Drug-resistant malaria in Thailand threatens d...
# 3220  U.S. drone strike kills key Pakistan Taliban c...
# 3221  BBC News - Hugo Chavez suffers 'complications'...
# 3222  Violent demonstrations injure dozens of police...
# 3223  After Outsourcing Boom, An 'Insourcing' Comeba...
#
#                                                   Top23  \
# 3219  In Myanmar, Muslim survivors recall Buddhist a...
# 3220  In the Middle East, the Arab spring has given ...
# 3221  60,000 Dead in Syria? Why the Death Toll Is Li...
# 3222  Morsi Expands Brotherhood Influence in Egyptia...
# 3223       British Soldier Killed By 'Uniformed Afghan'
#
#                                                   Top24  \
# 3219    Israeli-Palestinian Clashes Erupt in West Bank
# 3220  Rio geared towards bike-friendly future: Brazi...
# 3221  India. Assam women beat 'sex-attack politician...
# 3222                        The Greek island of old age
# 3223  Latest drone strike kills eight in northwest P...
#
#                                                   Top25
# 3219  Drop in North Korean refugees to South Korea. ...
# 3220  Delhi gang rape: Victim's father says juvenile...
# 3221         Anti-government protests rage across Iraq
# 3222  British Army accused of 'wrongly punishing' 1,...
# 3223  Indonesia's Aceh province proposes new law ban...
#
# [5 rows x 27 columns]

# %%
data = train_df.iloc[:,2:27]
data.head()
# Out:
#                                                 Top1  \
# 0  A 'hindrance to operations': extracts from the...
# 1                                          Scorecard
# 2                  Coventry caught on counter by Flo
# 3                      Pilgrim knows how to progress
# 4                               Hitches and Horlocks
#
#                                  Top2  \
# 0                           Scorecard
# 1                 The best lake scene
# 2  United's rivals on the road to Rio
# 3                 Thatcher facing ban
# 4      Beckham off but United survive
#
#                                             Top3  \
# 0                Hughes' instant hit buoys Blues
# 1                  Leader: German sleaze inquiry
# 2  Thatcher issues defence before trial by video
# 3        McIlroy calls for Irish fighting spirit
# 4                        Breast cancer screening
#
#                                             Top4  \
# 0       Jack gets his skates on at ice-cold Alex
# 1                                  Cheerio, boyo
# 2  Police help Smith lay down the law at Everton
# 3                Leicester bin stadium blueprint
# 4                                    Alan Parker
#
#                                           Top5  \
# 0       Chaos as Maracana builds up for United
# 1                     The main recommendations
# 2  Tale of Trautmann bears two more retellings
# 3               United braced for Mexican wave
# 4      Guardian readers: are you all whingers?
#
#                                                 Top6  \
# 0  Depleted Leicester prevail as Elliott spoils E...
# 1                             Has Cubie killed fees?
# 2                                England on the rack
# 3  Auntie back in fashion, even if the dress look...
# 4                                   Hollywood Beyond
#
#                                               Top7  \
# 0                 Hungry Spurs sense rich pickings
# 1                           Has Cubie killed fees?
# 2  Pakistan retaliate with call for video of Walsh
# 3                    Shoaib appeal goes to the top
# 4                               Ashes and diamonds
#
#                                                 Top8  \
# 0                  Gunners so wide of an easy target
# 1                             Has Cubie killed fees?
# 2               Cullinan continues his Cape monopoly
# 3  Hussain hurt by 'shambles' but lays blame on e...
# 4                   Whingers - a formidable minority
#
#                                                 Top9  \
# 0      Derby raise a glass to Strupar's debut double
# 1  Hopkins 'furious' at Foster's lack of Hannibal...
# 2             McGrath puts India out of their misery
# 3                      England's decade of disasters
# 4                             Alan Parker - part two
#
#                                       Top10  ...  \
# 0  Southgate strikes, Leeds pay the penalty  ...
# 1                    Has Cubie killed fees?  ...
# 2            Blair Witch bandwagon rolls on  ...
# 3      Revenge is sweet for jubilant Cronje  ...
# 4                 Thuggery, Toxins and Ties  ...
#
#                                                Top16  \
# 0           Flintoff injury piles on woe for England
# 1                               On the critical list
# 2                        South Melbourne (Australia)
# 3  Putin admits Yeltsin quit to give him a head s...
# 4                             Most everywhere:  UDIs
#
#                                                Top17  \
# 0  Hunters threaten Jospin with new battle of the...
# 1                          The timing of their lives
# 2                                    Necaxa (Mexico)
# 3         BBC worst hit as digital TV begins to bite
# 4                       Most wanted:  Chloe lunettes
#
#                                             Top18  \
# 0             Kohl's successor drawn into scandal
# 1                                     Dear doctor
# 2                             Real Madrid (Spain)
# 3                     How much can you pay for...
# 4  Return of the cane 'completely off the agenda'
#
#                                                Top19  \
# 0               The difference between men and women
# 1  Irish court halts IRA man's extradition to Nor...
# 2                          Raja Casablanca (Morocco)
# 3                                 Christmas glitches
# 4                   From Sleepy Hollow to Greeneland
#
#                                                Top20  \
# 0                Sara Denver, nurse turned solicitor
# 1  Burundi peace initiative fades after rebels re...
# 2                               Corinthians (Brazil)
# 3  Upending a table, Chopping a line and Scoring ...
# 4              Blunkett outlines vision for over 11s
#
#                                                Top21  \
# 0     Diana's landmine crusade put Tories in a panic
# 1               PE points the way forward to the ECB
# 2                                 Tony's pet project
# 3   Scientific evidence 'unreliable', defence claims
# 4  Embattled Dobson attacks 'play now, pay later'...
#
#                                                Top22  \
# 0  Yeltsin's resignation caught opposition flat-f...
# 1  Campaigners keep up pressure on Nazi war crime...
# 2                            Al Nassr (Saudi Arabia)
# 3     Fusco wins judicial review in extradition case
# 4                                  Doom and the Dome
#
#                              Top23  \
# 0                 Russian roulette
# 1                   Jane Ratcliffe
# 2                Ideal Holmes show
# 3    Rebels thwart Russian advance
# 4  What is the north-south divide?
#
#                                                Top24  \
# 0                                           Sold out
# 1  Yet more things you wouldn't know without the ...
# 2               Pinochet leaves hospital after tests
# 3               Blair orders shake-up of failing NHS
# 4                          Aitken released from jail
#
#                           Top25
# 0            Recovering a title
# 1  Millennium bug fails to bite
# 2                  Useful links
# 3   Lessons of law's hard heart
# 4                    Gone aloft
#
# [5 rows x 25 columns]

# %%
import re

data.replace("[^a-zA-Z]"," ",regex=True, inplace=True)

list1 = [i for i in range(25)]
new_Index = [str(i) for i in list1]
data.columns = new_Index

for index in new_Index:
    data[index] = data[index].str.lower()
    



data.head()
#for i in range(len(data)):
#    data[i] = data[i].append(sent for sent in data[i])
# Out:
#                                                    0  \
# 0  a  hindrance to operations   extracts from the...
# 1                                          scorecard
# 2                  coventry caught on counter by flo
# 3                      pilgrim knows how to progress
# 4                               hitches and horlocks
#
#                                     1  \
# 0                           scorecard
# 1                 the best lake scene
# 2  united s rivals on the road to rio
# 3                 thatcher facing ban
# 4      beckham off but united survive
#
#                                                2  \
# 0                hughes  instant hit buoys blues
# 1                  leader  german sleaze inquiry
# 2  thatcher issues defence before trial by video
# 3        mcilroy calls for irish fighting spirit
# 4                        breast cancer screening
#
#                                                3  \
# 0       jack gets his skates on at ice cold alex
# 1                                  cheerio  boyo
# 2  police help smith lay down the law at everton
# 3                leicester bin stadium blueprint
# 4                                    alan parker
#
#                                              4  \
# 0       chaos as maracana builds up for united
# 1                     the main recommendations
# 2  tale of trautmann bears two more retellings
# 3               united braced for mexican wave
# 4      guardian readers  are you all whingers
#
#                                                    5  \
# 0  depleted leicester prevail as elliott spoils e...
# 1                             has cubie killed fees
# 2                                england on the rack
# 3  auntie back in fashion  even if the dress look...
# 4                                   hollywood beyond
#
#                                                  6  \
# 0                 hungry spurs sense rich pickings
# 1                           has cubie killed fees
# 2  pakistan retaliate with call for video of walsh
# 3                    shoaib appeal goes to the top
# 4                               ashes and diamonds
#
#                                                    7  \
# 0                  gunners so wide of an easy target
# 1                             has cubie killed fees
# 2               cullinan continues his cape monopoly
# 3  hussain hurt by  shambles  but lays blame on e...
# 4                   whingers   a formidable minority
#
#                                                    8  \
# 0      derby raise a glass to strupar s debut double
# 1  hopkins  furious  at foster s lack of hannibal...
# 2             mcgrath puts india out of their misery
# 3                      england s decade of disasters
# 4                             alan parker   part two
#
#                                           9  ...  \
# 0  southgate strikes  leeds pay the penalty  ...
# 1                    has cubie killed fees   ...
# 2            blair witch bandwagon rolls on  ...
# 3      revenge is sweet for jubilant cronje  ...
# 4                 thuggery  toxins and ties  ...
#
#                                                   15  \
# 0           flintoff injury piles on woe for england
# 1                               on the critical list
# 2                        south melbourne  australia
# 3  putin admits yeltsin quit to give him a head s...
# 4                             most everywhere   udis
#
#                                                   16  \
# 0  hunters threaten jospin with new battle of the...
# 1                          the timing of their lives
# 2                                    necaxa  mexico
# 3         bbc worst hit as digital tv begins to bite
# 4                       most wanted   chloe lunettes
#
#                                                17  \
# 0             kohl s successor drawn into scandal
# 1                                     dear doctor
# 2                             real madrid  spain
# 3                     how much can you pay for
# 4  return of the cane  completely off the agenda
#
#                                                   18  \
# 0               the difference between men and women
# 1  irish court halts ira man s extradition to nor...
# 2                          raja casablanca  morocco
# 3                                 christmas glitches
# 4                   from sleepy hollow to greeneland
#
#                                                   19  \
# 0                sara denver  nurse turned solicitor
# 1  burundi peace initiative fades after rebels re...
# 2                               corinthians  brazil
# 3  upending a table  chopping a line and scoring ...
# 4              blunkett outlines vision for over   s
#
#                                                   20  \
# 0     diana s landmine crusade put tories in a panic
# 1               pe points the way forward to the ecb
# 2                                 tony s pet project
# 3   scientific evidence  unreliable   defence claims
# 4  embattled dobson attacks  play now  pay later ...
#
#                                                   21  \
# 0  yeltsin s resignation caught opposition flat f...
# 1  campaigners keep up pressure on nazi war crime...
# 2                            al nassr  saudi arabia
# 3     fusco wins judicial review in extradition case
# 4                                  doom and the dome
#
#                                 22  \
# 0                 russian roulette
# 1                   jane ratcliffe
# 2                ideal holmes show
# 3    rebels thwart russian advance
# 4  what is the north south divide
#
#                                                   23  \
# 0                                           sold out
# 1  yet more things you wouldn t know without the ...
# 2               pinochet leaves hospital after tests
# 3               blair orders shake up of failing nhs
# 4                          aitken released from jail
#
#                              24
# 0            recovering a title
# 1  millennium bug fails to bite
# 2                  useful links
# 3   lessons of law s hard heart
# 4                    gone aloft
#
# [5 rows x 25 columns]

# %%
headlines = []
for row in range(0,len(data.index)):

    headlines.append(' '.join(str(x) for x in data.iloc[row, 0:25]))

headlines[0]

#lets remove stopwords and do stemming

from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

ps = PorterStemmer()

for i in range(len(headlines)):

    if i % 500 == 0:
        print(f"Processing row {i}/{len(headlines)}")
    x = headlines[i]
    x = nltk.word_tokenize(x)
    x = [ps.stem(word) for word in x if word not in set(stopwords.words('english'))]
    headlines[i]= ' '.join(x)
# Out:
# Processing row 0/3219
# Processing row 500/3219
# Processing row 1000/3219
# Processing row 1500/3219
# Processing row 2000/3219
# Processing row 2500/3219
# Processing row 3000/3219

# %%
#Bag of Words
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier

cv = CountVectorizer(ngram_range=(2,2))
trainDataset = cv.fit_transform(headlines)

# %%
#RandomForestClassifier
randomForest = RandomForestClassifier(n_estimators=200, criterion ='entropy')
randomForest.fit(trainDataset, train_df['Label'])
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=200)

# %%
testTransform = []

for row in range(0, len(test_df.index)):
    testTransform.append(' '.join(str(x) for x in test_df.iloc[row, 2:27]))


for i in range(len(testTransform)):

    if i % 500 == 0:
        print(f"Processing row {i}/{len(testTransform)}")
    x = re.sub( '[^a-zA-Z]', ' ',testTransform[i])
    x= x.lower()
    x = nltk.word_tokenize(x)
    x = [ps.stem(word) for word in x if word not in set(stopwords.words('english'))]
    testTransform[i]= ' '.join(x)
# Out:
# Processing row 0/882
# Processing row 500/882

# %%
testDataset = cv.transform(testTransform)

# %%
predictions = randomForest.predict(testDataset)

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
matrix=confusion_matrix(test_df['Label'],predictions)
print(matrix)
score=accuracy_score(test_df['Label'],predictions)
print(score)
report=classification_report(test_df['Label'],predictions)
print(report)
# Out:
# [[ 13 392]
#  [ 12 465]]
# 0.5419501133786848
#               precision    recall  f1-score   support
#
#            0       0.52      0.03      0.06       405
#            1       0.54      0.97      0.70       477
#
#     accuracy                           0.54       882
#    macro avg       0.53      0.50      0.38       882
# weighted avg       0.53      0.54      0.40       882
